# %% [markdown]
# # Module 03 - Data Wrangling with Pandas
#
# ---
#
# #### <a href="linkedin.com/in/tasmim-rahman-adib-403074221">Tasmim Rahman Adib</a>
#
# # Lecture 4.2 - Subset Observations - Rows
# ## Agenda
# - Display Options and Methods
# - Based on Condition
# - Rows with `isin()`
# - Using iloc
# - `query()`
# - Regex Pattern Matching
# - Based on Specific Columns' Presence
# - using `between()`
# - Group Statistics

# %% [markdown]
# ### 4.2.1 Pandas Display Options and the methods `head()` & `tail()`

# %%
import pandas as pd

# %%
# reading data 
df = pd.read_excel("../data/LungCapData.xls")

# %%
# show entire dataframe 
df
# Out:
#      LungCap  Age  Height Smoke  Gender Caesarean
# 0      6.475    6    62.1    no    male        no
# 1     10.125   18    74.7   yes  female        no
# 2      9.550   16    69.7    no  female       yes
# 3     11.125   14    71.0    no    male        no
# 4      4.800    5    56.9    no    male        no
# ..       ...  ...     ...   ...     ...       ...
# 720    5.725    9    56.0    no  female        no
# 721    9.050   18    72.0   yes    male       yes
# 722    3.850   11    60.5   yes  female        no
# 723    9.825   15    64.9    no  female        no
# 724    7.100   10    67.7    no    male        no
#
# [725 rows x 6 columns]

# %%
# print dataframe 
print(df)
# Out:
#      LungCap  Age  Height Smoke  Gender Caesarean
# 0      6.475    6    62.1    no    male        no
# 1     10.125   18    74.7   yes  female        no
# 2      9.550   16    69.7    no  female       yes
# 3     11.125   14    71.0    no    male        no
# 4      4.800    5    56.9    no    male        no
# ..       ...  ...     ...   ...     ...       ...
# 720    5.725    9    56.0    no  female        no
# 721    9.050   18    72.0   yes    male       yes
# 722    3.850   11    60.5   yes  female        no
# 723    9.825   15    64.9    no  female        no
# 724    7.100   10    67.7    no    male        no
#
# [725 rows x 6 columns]

# %%
# max rows 
pd.options.display.max_rows
# Out:
# 60

# %%
# min rows 
pd.options.display.min_rows
# Out:
# 10

# %%
# examine first few rows(default 5 rows)
df.head()
# Out:
#    LungCap  Age  Height Smoke  Gender Caesarean
# 0    6.475    6    62.1    no    male        no
# 1   10.125   18    74.7   yes  female        no
# 2    9.550   16    69.7    no  female       yes
# 3   11.125   14    71.0    no    male        no
# 4    4.800    5    56.9    no    male        no

# %%
# examine first few rows(n = 10)
df.head(10)
# Out:
#    LungCap  Age  Height Smoke  Gender Caesarean
# 0    6.475    6    62.1    no    male        no
# 1   10.125   18    74.7   yes  female        no
# 2    9.550   16    69.7    no  female       yes
# 3   11.125   14    71.0    no    male        no
# 4    4.800    5    56.9    no    male        no
# 5    6.225   11    58.7    no  female        no
# 6    4.950    8    63.3    no    male       yes
# 7    7.325   11    70.4    no    male        no
# 8    8.875   15    70.5    no    male        no
# 9    6.800   11    59.2    no    male        no

# %%
# examine last few rows(default = 5)
df.tail()
# Out:
#      LungCap  Age  Height Smoke  Gender Caesarean
# 720    5.725    9    56.0    no  female        no
# 721    9.050   18    72.0   yes    male       yes
# 722    3.850   11    60.5   yes  female        no
# 723    9.825   15    64.9    no  female        no
# 724    7.100   10    67.7    no    male        no

# %%
# examine first few rows(n = 10)
df.tail(6)
# Out:
#      LungCap  Age  Height Smoke  Gender Caesarean
# 719    7.325    9    66.3    no    male        no
# 720    5.725    9    56.0    no  female        no
# 721    9.050   18    72.0   yes    male       yes
# 722    3.850   11    60.5   yes  female        no
# 723    9.825   15    64.9    no  female        no
# 724    7.100   10    67.7    no    male        no

# %% [markdown]
# ### 4.2.2 Subset rows based on Condition

# %%
# Subset rows where column 'Age' is greater than 15
subset_df = df[df['Age'] > 15]
subset_df.head()
# Out:
#     LungCap  Age  Height Smoke  Gender Caesarean
# 1    10.125   18    74.7   yes  female        no
# 2     9.550   16    69.7    no  female       yes
# 10   11.500   19    76.4    no    male       yes
# 11   10.925   17    71.7    no    male        no
# 22   10.025   16    72.4    no    male        no

# %%
# Multiple Conditions
# Subset rows where 'Age' is greater than 30 and 'Gender' is 'male'
subset_df = df[(df['Age'] > 15) & (df['Gender'] == 'male')]
subset_df
# Out:
#      LungCap  Age  Height Smoke Gender Caesarean
# 10    11.500   19    76.4    no   male       yes
# 11    10.925   17    71.7    no   male        no
# 22    10.025   16    72.4    no   male        no
# 39    11.325   17    77.7    no   male        no
# 48    12.950   17    74.9    no   male        no
# ..       ...  ...     ...   ...    ...       ...
# 676   13.325   18    76.9   yes   male        no
# 697    6.450   16    66.5   yes   male        no
# 710   12.325   17    73.5    no   male        no
# 718    7.175   17    68.8    no   male       yes
# 721    9.050   18    72.0   yes   male       yes
#
# [89 rows x 6 columns]

# %% [markdown]
# ### 4.2.3 Subset Rows with `isin()`

# %%
df = pd.read_excel("../data/covid19_multiple_sheets.xlsx", sheet_name = 'day1')
df
# Out:
#     Province/State          Country/Region      Last Update  Confirmed  \
# 0            Hubei          Mainland China  3/13/2020 06:00      67786
# 1        Guangdong          Mainland China  3/13/2020 06:00       1356
# 2         Zhejiang          Mainland China  3/13/2020 06:00       1215
# 3         Shandong          Mainland China  3/13/2020 06:00        760
# 4            Henan          Mainland China  3/13/2020 06:00       1273
# ..             ...                     ...              ...        ...
# 216            NaN                Mongolia  3/13/2020 06:00          1
# 217            NaN               St. Barth  3/13/2020 06:00          1
# 218            NaN  St. Vincent Grenadines  3/13/2020 06:00          1
# 219            NaN                    Togo  3/13/2020 06:00          1
# 220            NaN     Trinidad and Tobago  3/13/2020 06:00          1
#
#      Deaths  Recovered
# 0      3062      51553
# 1         8       1296
# 2         1       1209
# 3         7        739
# 4        22       1249
# ..      ...        ...
# 216       0          0
# 217       0          0
# 218       0          0
# 219       0          0
# 220       0          0
#
# [221 rows x 6 columns]

# %%
# Subset rows where 'Country/Region' is either 'US' or 'Thailand'
subset_df = df[df['Country/Region'].isin(['US', 'Thailand'])]
subset_df
# Out:
#                    Province/State Country/Region      Last Update  Confirmed  \
# 38                             WA             US  3/13/2020 06:00        457
# 39                       New York             US  3/13/2020 06:00        325
# 40                     California             US  3/13/2020 06:00        243
# 41                  Massachusetts             US  3/13/2020 06:00        108
# 42                        Florida             US  3/13/2020 06:00         50
# 43                       Colorado             US  3/13/2020 06:00         50
# 44   From Diamond Princess cruise             US  3/13/2020 06:00         45
# 45                        Georgia             US  3/13/2020 06:00         38
# 46                       Illinois             US  3/13/2020 06:00         32
# 47                          Texas             US  3/13/2020 06:00         32
# 48                     New Jersey             US  3/13/2020 06:00         31
# 49                         Oregon             US  3/13/2020 06:00         24
# 50                   Pennsylvania             US  3/13/2020 06:00         22
# 51            From Grand Princess             US  3/13/2020 06:00         21
# 52                      Louisiana             US  3/13/2020 06:00         19
# 53                      Tennessee             US  3/13/2020 06:00         18
# 54                       Virginia             US  3/13/2020 06:00         18
# 55                 North Carolina             US  3/13/2020 06:00         17
# 56                           Iowa             US  3/13/2020 06:00         16
# 57                        Indiana             US  3/13/2020 06:00         13
# 58                       Maryland             US  3/13/2020 06:00         12
# 59                 South Carolina             US  3/13/2020 06:00         12
# 60                       Michigan             US  3/13/2020 06:00         12
# 61                         Nevada             US  3/13/2020 06:00         11
# 62                       Kentucky             US  3/13/2020 06:00         11
# 63                       Nebraska             US  3/13/2020 06:00         11
# 64                  Washington DC             US  3/13/2020 06:00         10
# 65                        Arizona             US  3/13/2020 06:00          9
# 66                      Minnesota             US  3/13/2020 06:00          9
# 67                      Wisconsin             US  3/13/2020 06:00          8
# 68                   South Dakota             US  3/13/2020 06:00          8
# 69                  New Hampshire             US  3/13/2020 06:00          6
# 70                     New Mexico             US  3/13/2020 06:00          6
# 71                       Arkansas             US  3/13/2020 06:00          6
# 72                   Rhode Island             US  3/13/2020 06:00          5
# 73                           Utah             US  3/13/2020 06:00          5
# 74                         Kansas             US  3/13/2020 06:00          5
# 75                    Connecticut             US  3/13/2020 06:00          5
# 76                           Ohio             US  3/13/2020 06:00          5
# 77                       Delaware             US  3/13/2020 06:00          4
# 78                       Oklahoma             US  3/13/2020 06:00          3
# 79                         Hawaii             US  3/13/2020 06:00          2
# 80                       Missouri             US  3/13/2020 06:00          2
# 81                        Vermont             US  3/13/2020 06:00          2
# 82                    Mississippi             US  3/13/2020 06:00          1
# 83                        Wyoming             US  3/13/2020 06:00          1
# 84                   North Dakota             US  3/13/2020 06:00          1
# 85                        Montana             US  3/13/2020 06:00          1
# 86                          Maine             US  3/13/2020 06:00          1
# 87                         Alaska             US  3/13/2020 06:00          1
# 131                           NaN       Thailand  3/13/2020 06:00         75
#
#      Deaths  Recovered
# 38       31          1
# 39        0          0
# 40        4          6
# 41        0          1
# 42        2          0
# 43        0          0
# 44        0          0
# 45        1          0
# 46        0          2
# 47        0          0
# 48        1          0
# 49        0          0
# 50        0          0
# 51        0          0
# 52        0          0
# 53        0          0
# 54        0          0
# 55        0          0
# 56        0          0
# 57        0          0
# 58        0          0
# 59        0          0
# 60        0          0
# 61        0          0
# 62        0          0
# 63        0          0
# 64        0          0
# 65        0          1
# 66        0          0
# 67        0          1
# 68        1          0
# 69        0          0
# 70        0          0
# 71        0          0
# 72        0          0
# 73        0          0
# 74        0          0
# 75        0          0
# 76        0          0
# 77        0          0
# 78        0          0
# 79        0          0
# 80        0          0
# 81        0          0
# 82        0          0
# 83        0          0
# 84        0          0
# 85        0          0
# 86        0          0
# 87        0          0
# 131       1         35

# %%
# Subset rows where 'Province/State' is not 'Henan'
subset_df = df[~df['Country/Region'].isin(['US'])]
subset_df
# Out:
#     Province/State          Country/Region      Last Update  Confirmed  \
# 0            Hubei          Mainland China  3/13/2020 06:00      67786
# 1        Guangdong          Mainland China  3/13/2020 06:00       1356
# 2         Zhejiang          Mainland China  3/13/2020 06:00       1215
# 3         Shandong          Mainland China  3/13/2020 06:00        760
# 4            Henan          Mainland China  3/13/2020 06:00       1273
# ..             ...                     ...              ...        ...
# 216            NaN                Mongolia  3/13/2020 06:00          1
# 217            NaN               St. Barth  3/13/2020 06:00          1
# 218            NaN  St. Vincent Grenadines  3/13/2020 06:00          1
# 219            NaN                    Togo  3/13/2020 06:00          1
# 220            NaN     Trinidad and Tobago  3/13/2020 06:00          1
#
#      Deaths  Recovered
# 0      3062      51553
# 1         8       1296
# 2         1       1209
# 3         7        739
# 4        22       1249
# ..      ...        ...
# 216       0          0
# 217       0          0
# 218       0          0
# 219       0          0
# 220       0          0
#
# [171 rows x 6 columns]

# %% [markdown]
# ### 4.2.4 using `iloc`

# %%
# Subset the first 10 rows
subset_df = df.iloc[:10]
subset_df
# Out:
#   Province/State  Country/Region      Last Update  Confirmed  Deaths  \
# 0          Hubei  Mainland China  3/13/2020 06:00      67786    3062
# 1      Guangdong  Mainland China  3/13/2020 06:00       1356       8
# 2       Zhejiang  Mainland China  3/13/2020 06:00       1215       1
# 3       Shandong  Mainland China  3/13/2020 06:00        760       7
# 4          Henan  Mainland China  3/13/2020 06:00       1273      22
# 5          Anhui  Mainland China  3/13/2020 06:00        990       6
# 6        Jiangxi  Mainland China  3/13/2020 06:00        935       1
# 7          Hunan  Mainland China  3/13/2020 06:00       1018       4
# 8   Heilongjiang  Mainland China  3/13/2020 06:00        482      13
# 9        Sichuan  Mainland China  3/13/2020 06:00        539       3
#
#    Recovered
# 0      51553
# 1       1296
# 2       1209
# 3        739
# 4       1249
# 5        984
# 6        934
# 7       1005
# 8        446
# 9        503

# %%
# Subset the rows after 10
subset_df = df.iloc[10:]
subset_df
# Out:
#     Province/State          Country/Region      Last Update  Confirmed  \
# 10       Chongqing          Mainland China  3/13/2020 06:00        576
# 11         Jiangsu          Mainland China  3/13/2020 06:00        631
# 12         Beijing          Mainland China  3/13/2020 06:00        436
# 13         Guangxi          Mainland China  3/13/2020 06:00        252
# 14          Fujian          Mainland China  3/13/2020 06:00        296
# ..             ...                     ...              ...        ...
# 216            NaN                Mongolia  3/13/2020 06:00          1
# 217            NaN               St. Barth  3/13/2020 06:00          1
# 218            NaN  St. Vincent Grenadines  3/13/2020 06:00          1
# 219            NaN                    Togo  3/13/2020 06:00          1
# 220            NaN     Trinidad and Tobago  3/13/2020 06:00          1
#
#      Deaths  Recovered
# 10        6        564
# 11        0        630
# 12        8        342
# 13        2        243
# 14        1        295
# ..      ...        ...
# 216       0          0
# 217       0          0
# 218       0          0
# 219       0          0
# 220       0          0
#
# [211 rows x 6 columns]

# %%
# rows from 1 to before 4
df.iloc[1:4]
# Out:
#   Province/State  Country/Region      Last Update  Confirmed  Deaths  \
# 1      Guangdong  Mainland China  3/13/2020 06:00       1356       8
# 2       Zhejiang  Mainland China  3/13/2020 06:00       1215       1
# 3       Shandong  Mainland China  3/13/2020 06:00        760       7
#
#    Recovered
# 1       1296
# 2       1209
# 3        739

# %%
# getting row index is 1
df.iloc[1]
# Out:
# Province/State          Guangdong
# Country/Region     Mainland China
# Last Update       3/13/2020 06:00
# Confirmed                    1356
# Deaths                          8
# Recovered                    1296
# Name: 1, dtype: object

# %%
# getting the last row
df.iloc[-1]
# Out:
# Province/State                    NaN
# Country/Region    Trinidad and Tobago
# Last Update           3/13/2020 06:00
# Confirmed                           1
# Deaths                              0
# Recovered                           0
# Name: 220, dtype: object

# %%
# finding value for row 0 and column 4
df.iloc[0, 4]
# Out:
# np.int64(3062)

# %%
# finding first 3 columns value for row 0
df.iloc[0, :3]
# Out:
# Province/State              Hubei
# Country/Region     Mainland China
# Last Update       3/13/2020 06:00
# Name: 0, dtype: object

# %%
# get 0, 2 and 5 number columns values for row index 34 to 39
df.iloc[34:39, [0, 2, 5]]
# Out:
#                   Province/State      Last Update  Recovered
# 34               South Australia  3/13/2020 06:00          3
# 35             Western Australia  3/13/2020 06:00          0
# 36                      Tasmania  3/13/2020 06:00          0
# 37  Australian Capital Territory  3/13/2020 06:00          0
# 38                            WA  3/13/2020 06:00          1

# %% [markdown]
# ### 4.2.5 Subset rows using `query()`

# %%
# Subset rows where 'Age' is greater than 25 and 'Salary' is less than 50000
df.query('Deaths > 5 and Recovered < 500')
# Out:
#     Province/State  Country/Region      Last Update  Confirmed  Deaths  \
# 8     Heilongjiang  Mainland China  3/13/2020 06:00        482      13
# 12         Beijing  Mainland China  3/13/2020 06:00        436       8
# 16           Hebei  Mainland China  3/13/2020 06:00        318       6
# 20          Hainan  Mainland China  3/13/2020 06:00        168       6
# 38              WA              US  3/13/2020 06:00        457      31
# 98             NaN           Spain  3/13/2020 06:00       3779      87
# 99             NaN          France  3/13/2020 06:00       2876      61
# 100            NaN         Germany  3/13/2020 06:00       2750       6
# 101            NaN     Switzerland  3/13/2020 06:00        868       7
# 104            NaN           Japan  3/13/2020 06:00        701      19
# 105       Yokohama           Japan  3/13/2020 06:00        696       7
# 108            NaN              UK  3/13/2020 06:00        590      10
# 123            NaN            Iraq  3/13/2020 06:00         83       8
#
#      Recovered
# 8          446
# 12         342
# 16         310
# 20         160
# 38           1
# 98         189
# 99          12
# 100         25
# 101          4
# 104        118
# 105        325
# 108         18
# 123         24

# %% [markdown]
# ### 4.2.6 Subset rows Using Regex Pattern

# %%
# Subset rows where the 'Country/Region' column contains 'land'
df[df['Country/Region'].str.contains('land', case=False)]
# Out:
#      Province/State   Country/Region      Last Update  Confirmed  Deaths  \
# 0             Hubei   Mainland China  3/13/2020 06:00      67786    3062
# 1         Guangdong   Mainland China  3/13/2020 06:00       1356       8
# 2          Zhejiang   Mainland China  3/13/2020 06:00       1215       1
# 3          Shandong   Mainland China  3/13/2020 06:00        760       7
# 4             Henan   Mainland China  3/13/2020 06:00       1273      22
# 5             Anhui   Mainland China  3/13/2020 06:00        990       6
# 6           Jiangxi   Mainland China  3/13/2020 06:00        935       1
# 7             Hunan   Mainland China  3/13/2020 06:00       1018       4
# 8      Heilongjiang   Mainland China  3/13/2020 06:00        482      13
# 9           Sichuan   Mainland China  3/13/2020 06:00        539       3
# 10        Chongqing   Mainland China  3/13/2020 06:00        576       6
# 11          Jiangsu   Mainland China  3/13/2020 06:00        631       0
# 12          Beijing   Mainland China  3/13/2020 06:00        436       8
# 13          Guangxi   Mainland China  3/13/2020 06:00        252       2
# 14           Fujian   Mainland China  3/13/2020 06:00        296       1
# 15         Shanghai   Mainland China  3/13/2020 06:00        346       3
# 16            Hebei   Mainland China  3/13/2020 06:00        318       6
# 17          Shaanxi   Mainland China  3/13/2020 06:00        245       2
# 18           Yunnan   Mainland China  3/13/2020 06:00        174       2
# 19          Tianjin   Mainland China  3/13/2020 06:00        136       3
# 20           Hainan   Mainland China  3/13/2020 06:00        168       6
# 21          Guizhou   Mainland China  3/13/2020 06:00        146       2
# 22         Liaoning   Mainland China  3/13/2020 06:00        125       1
# 23           Shanxi   Mainland China  3/13/2020 06:00        133       0
# 24   Inner Mongolia   Mainland China  3/13/2020 06:00         75       1
# 25         Xinjiang   Mainland China  3/13/2020 06:00         76       3
# 26            Jilin   Mainland China  3/13/2020 06:00         93       1
# 27          Ningxia   Mainland China  3/13/2020 06:00         75       0
# 28            Gansu   Mainland China  3/13/2020 06:00        127       2
# 29          Qinghai   Mainland China  3/13/2020 06:00         18       0
# 30            Tibet   Mainland China  3/13/2020 06:00          1       0
# 101             NaN      Switzerland  3/13/2020 06:00        868       7
# 107             NaN      Netherlands  3/13/2020 06:00        614       5
# 115             NaN          Finland  3/13/2020 06:00        155       0
# 120             NaN          Iceland  3/13/2020 06:00        117       0
# 131             NaN         Thailand  3/13/2020 06:00         75       1
# 132             NaN          Ireland  3/13/2020 06:00         70       1
# 135             NaN           Poland  3/13/2020 06:00         61       1
# 184             NaN      New Zealand  3/13/2020 06:00          5       0
# 192             NaN  Channel Islands  3/13/2020 06:00          3       0
# 194             NaN   Faeroe Islands  3/13/2020 06:00          3       0
# 211             NaN   Cayman Islands  3/13/2020 06:00          1       0
#
#      Recovered
# 0        51553
# 1         1296
# 2         1209
# 3          739
# 4         1249
# 5          984
# 6          934
# 7         1005
# 8          446
# 9          503
# 10         564
# 11         630
# 12         342
# 13         243
# 14         295
# 15         324
# 16         310
# 17         232
# 18         170
# 19         132
# 20         160
# 21         140
# 22         112
# 23         133
# 24          71
# 25          73
# 26          91
# 27          72
# 28          88
# 29          18
# 30           1
# 101          4
# 107          2
# 115          1
# 120          0
# 131         35
# 132          0
# 135          0
# 184          0
# 192          0
# 194          0
# 211          0

# %% [markdown]
# ### 4.2.6 Subset rows on date conditions

# %%
# Subset rows where 'Date' is between '2023-01-01' and '2023-12-31'
df[(df['Last Update'] >= '3/13/2020') & (df['Last Update'] <= '3/14/2020')]
# Out:
#     Province/State          Country/Region      Last Update  Confirmed  \
# 0            Hubei          Mainland China  3/13/2020 06:00      67786
# 1        Guangdong          Mainland China  3/13/2020 06:00       1356
# 2         Zhejiang          Mainland China  3/13/2020 06:00       1215
# 3         Shandong          Mainland China  3/13/2020 06:00        760
# 4            Henan          Mainland China  3/13/2020 06:00       1273
# ..             ...                     ...              ...        ...
# 216            NaN                Mongolia  3/13/2020 06:00          1
# 217            NaN               St. Barth  3/13/2020 06:00          1
# 218            NaN  St. Vincent Grenadines  3/13/2020 06:00          1
# 219            NaN                    Togo  3/13/2020 06:00          1
# 220            NaN     Trinidad and Tobago  3/13/2020 06:00          1
#
#      Deaths  Recovered
# 0      3062      51553
# 1         8       1296
# 2         1       1209
# 3         7        739
# 4        22       1249
# ..      ...        ...
# 216       0          0
# 217       0          0
# 218       0          0
# 219       0          0
# 220       0          0
#
# [221 rows x 6 columns]

# %% [markdown]
# ### 4.2.7 Based on specific columns' presence

# %%
# Subset rows where 'Country/Region' column values are in a specific list
countries = ['Brazil', 'Thailand', 'Bangladesh']
df[df['Country/Region'].isin(countries)]
# Out:
#     Province/State Country/Region      Last Update  Confirmed  Deaths  \
# 130            NaN         Brazil  3/13/2020 06:00         77       0
# 131            NaN       Thailand  3/13/2020 06:00         75       1
# 190            NaN     Bangladesh  3/13/2020 06:00          3       0
#
#      Recovered
# 130          0
# 131         35
# 190          0

# %% [markdown]
# ### 4.2.8 Subset rows using `between()`

# %%
# Subset rows where 'Deaths' is between 20 and 40
df[df['Deaths'].between(20, 40)]
# Out:
#    Province/State  Country/Region      Last Update  Confirmed  Deaths  \
# 4           Henan  Mainland China  3/13/2020 06:00       1273      22
# 38             WA              US  3/13/2020 06:00        457      31
#
#     Recovered
# 4        1249
# 38          1

# %% [markdown]
# ### 4.2.9 Subset rows based on Group Statistics

# %%
# Subset rows where 'Deaths' is greater than the mean 'Deaths' in the dataset
mean_death = df['Deaths'].mean()
df[df['Deaths'] > mean_death]
# Out:
#    Province/State  Country/Region      Last Update  Confirmed  Deaths  \
# 0           Hubei  Mainland China  3/13/2020 06:00      67786    3062
# 38             WA              US  3/13/2020 06:00        457      31
# 95            NaN           Italy  3/13/2020 06:00      15113    1016
# 96            NaN            Iran  3/13/2020 06:00      10075     429
# 97            NaN     South Korea  3/13/2020 06:00       7979      71
# 98            NaN           Spain  3/13/2020 06:00       3779      87
# 99            NaN          France  3/13/2020 06:00       2876      61
#
#     Recovered
# 0       51553
# 38          1
# 95       1258
# 96       3276
# 97        510
# 98        189
# 99         12
